# %% [markdown]
# <a href="https://colab.research.google.com/github/Farid-Alareqi/-Ayrik-Sistemler-icin-ileri-Olasilik/blob/main/Permutation_and_Combination.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Permutation
# A permutation is the choice of **r** things from a set of **n** things in which **order matters**.
#
# Permutation is denoted by
#
# ![image.png](data:image/png;base64,...)
#
# #Example:
# What order could 16 pool balls be in?
#
#  ![image.png](data:image/png;base64,...)
#
# After choosing the first ball, say, number "8" we can't choose it again.
#
# So, our first choice has 16 possibilites, and our next choice has 15 possibilities, then 14, 13, 12, 11, ... etc. And the total permutations are:
#
# 16 × 15 × 14 × 13 × ... = 20,922,789,888,000
#
# But maybe we only want to choose just 3 of them, and that is then:
#
# 16 × 15 × 14 = 3,360
#
# In other words, there are 3,360 different ways that 3 pool balls could be arranged out of 16 balls.
#
#  Mathematically using the formula that can be written as :
#
#  16!/(16−3)! = 16!/13! = 20,922,789,888,000/6,227,020,800 = 3,360

# %% [markdown]
# ---
#
#
# #Combination
# A comination is the choice of **r** things from a set of **n** things in which **order does not matters**.
#
# Comination is denoted by
#
# ![image.png](data:image/png;base64,...)
#
#
# #Example:
#
# How many times can 3 balls be selected out of 16 pool balls?
#
# ![image.png](data:image/png;base64,...)
#
# Let's use the formula
#
# 16!/3!(16−3)! = 16!/3! × 13!= 20,922,789,888,000/6 × 6,227,020,800 = 560
#
# So choosing 3 balls out of 16 have 560 possibilites.

# %% [markdown]
# ---
#
#
# #Permutation and Combination in Python
#
# We can use Python itertools library that is built-in to calculate permutation and combination.

# %% [markdown]
# #Permutation example

# %%
import itertools 
from itertools import permutations
# Define a function to calculate permutations for pool balls example

def calc_permutation(n,r):
      *per,=permutations(n,r)

      print("The number of possibilities that",r,"balls out of",len(n),"pool balls can be arranged are: ",len(per), end='\n')

      print(*per,sep="--")

# Create strings of the 16 balls
Pool_ball=[str(x+1) for x in range(16)]
# Calculate permutations of 3 balls
calc_permutation(Pool_ball,3)

# %% [markdown]
# ---
#
#
# #Combination example

# %%
import itertools 
from itertools import combinations
# Define a function to calculate combinations for pool balls example

def calc_combination(n,r):
      *com,=combinations(n,r)

      print("The number of possibilities that",r,"balls out of",len(n),"pool balls can be selected are: ",len(com), end='\n')

      print(*com,sep="--")

# Create strings of the 16 balls
Pool_ball=[str(x+1) for x in range(16)]
# Calculate combinations of 3 balls
calc_combination(Pool_ball,3)
